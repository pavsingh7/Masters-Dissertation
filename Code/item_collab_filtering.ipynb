# %%
# reset directory
# %reset -f

# load libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity

# %%
# read in data
books = pd.read_csv(r"c:\Users\e1002902\Downloads\archive\Books_rating.csv")

# %%
books.head(2)
# Out:
#            Id                           Title  Price         User_id  \
# 0  1882931173  Its Only Art If Its Well Hung!    NaN   AVCGYZL8FQQTD
# 1  0826414346        Dr. Seuss: American Icon    NaN  A30TK6U7DNS82R
#
#              profileName review/helpfulness  review/score  review/time  \
# 0  Jim of Oz "jim-of-oz"                7/7           4.0    940636800
# 1          Kevin Killian              10/10           5.0   1095724800
#
#                            review/summary  \
# 0  Nice collection of Julie Strain images
# 1                       Really Enjoyed It
#
#                                          review/text
# 0  This is only for Julie Strain fans. It's a col...
# 1  I don't care much for Dr. Seuss but after read...

# %% [markdown]
# # Cleaning Data
#
# 1. Remove Duplicate reviews
#
# 2. Remove books with less than 10 reviews
#
# 3. Remove users with less than 10 reviews

# %%
books = books[['User_id', 'Title', 'review/score', 'review/text']]
books
# Out:
#                 User_id                           Title  review/score  \
# 0         AVCGYZL8FQQTD  Its Only Art If Its Well Hung!           4.0
# 1        A30TK6U7DNS82R        Dr. Seuss: American Icon           5.0
# 2        A3UH4UZ4RSVO82        Dr. Seuss: American Icon           5.0
# 3        A2MVUWT453QH61        Dr. Seuss: American Icon           4.0
# 4        A22X4XUPKF66MR        Dr. Seuss: American Icon           4.0
# ...                 ...                             ...           ...
# 2999995             NaN             The Idea of History           4.0
# 2999996  A1SMUB9ASL5L9Y             The Idea of History           4.0
# 2999997  A2AQMEKZKK5EE4             The Idea of History           4.0
# 2999998  A18SQGYBKS852K             The Idea of History           5.0
# 2999999             NaN             The Idea of History           1.0
#
#                                                review/text
# 0        This is only for Julie Strain fans. It's a col...
# 1        I don't care much for Dr. Seuss but after read...
# 2        If people become the books they read and if "t...
# 3        Theodore Seuss Geisel (1904-1991), aka &quot;D...
# 4        Philip Nel - Dr. Seuss: American IconThis is b...
# ...                                                    ...
# 2999995  This is an extremely difficult book to digest,...
# 2999996  This is pretty interesting. Collingwood seems ...
# 2999997  This is a good book but very esoteric. "What i...
# 2999998  My daughter, a freshman at Indiana University,...
# 2999999  The guy has a few good ideas but, reader, bewa...
#
# [3000000 rows x 4 columns]

# %%
# count number of duplicates
print("Number duplicate reviews", books.duplicated().sum())

# see duplicates
print("Duplicates")
display(books[books.duplicated(keep=False)].head(10))

# remove duplicates
books.drop_duplicates(inplace=True)
# Out:
# Number duplicate reviews 380279
# Duplicates
#             User_id                                              Title  \
# 253             NaN  King James: Believe the Hype---The LeBron Jame...
# 256             NaN  King James: Believe the Hype---The LeBron Jame...
# 389  A3FJAY5LKN0DOM             The book of the lover and the beloved;
# 390   A2SVFGRQB3DHZ             The book of the lover and the beloved;
# 422             NaN                 Night World: Daughters Of Darkness
# 423             NaN                 Night World: Daughters Of Darkness
# 428             NaN                 Night World: Daughters Of Darkness
# 429             NaN                 Night World: Daughters Of Darkness
# 529             NaN                 America at 1750: A Social Portrait
# 530  A3DKP67DK28RUB                 America at 1750: A Social Portrait
#
#      review/score                                        review/text
# 253           4.0  King James by Ryan Jones is a biography of Leb...
# 256           4.0  King James by Ryan Jones is a biography of Leb...
# 389           5.0  A friend gave me this book a couple of years a...
# 390           4.0  If sometimes the meaning is inaccessible the e...
# 422           5.0  This book was outstanding! I couldn't put it d...
# 423           5.0  This book was outstanding! I couldn't put it d...
# 428           5.0  I was sceptical about this book at first, I ha...
# 429           5.0  I was sceptical about this book at first, I ha...
# 529           5.0  The brilliant historian Richard Hofstadter was...
# 530           5.0  This is a magnificent work of historical imagi...

# %%
# drop rows with missing values in review/text, review/score, Title and User_id
books.dropna(subset=['review/text', 'review/score', 'Title', 'User_id'], inplace=True)

# %%
# check data 
print("Shape of data", books.shape)
print("Number of unique users", books.User_id.nunique())
print("Number of unique books", books.Title.nunique())
# Out:
# Shape of data (2132528, 4)
# Number of unique users 1008961
# Number of unique books 206711

# %%
# get count of reviews per book
book_review_count = books.groupby('Title')['review/score'].count().reset_index().rename(columns={'review/score':'review_count'}).sort_values('review_count', ascending=False)

# How many books with less than 10 reviews?
print("How many books with less than 10 reviews:", book_review_count[book_review_count.review_count < 30].shape)

# remove books with less than 10 reviews
books = books[books.Title.isin(book_review_count[book_review_count.review_count > 30].Title)]

# get updated info on data
print("Shape of data", books.shape)
print("Number of unique users", books.User_id.nunique())
print("Number of unique books", books.Title.nunique())
# Out:
# How many books with less than 10 reviews: (13428, 2)
# Shape of data (129592, 4)
# Number of unique users 4539
# Number of unique books 1727

# %%
# get count of reviews per user
user_review_count = books.groupby('User_id')['review/score'].count().reset_index().rename(columns={'review/score':'review_count'}).sort_values('review_count', ascending=False)

# How many users with less than 20 reviews?
print("Number users with less than 20 reviews", user_review_count[user_review_count.review_count > 20].shape)

# remove users with less than 20 reviews
books = books[books.User_id.isin(user_review_count[user_review_count.review_count > 20].User_id)]

# get updated info on data
print("Shape of data", books.shape)
print("Number of unique users", books.User_id.nunique())
print("Number of unique books", books.Title.nunique())
display(books.head(3))
# Out:
# Number users with less than 20 reviews (2249, 2)
# Shape of data (101149, 4)
# Number of unique users 2249
# Number of unique books 1727
#              User_id                    Title  review/score  \
# 1222   AF3X7J0XC391L  Economics in one lesson           5.0
# 1249  A321W4SSC0F6AP  Economics in one lesson           5.0
# 1260  A3JPFWKS83R49V  Economics in one lesson           4.0
#
#                                             review/text
# 1222  This is, in my opinion, the most important int...
# 1249  You know how most economics books are really, ...
# 1260  Author Henry Hazlitt is definitely a member of...

# %% [markdown]
# ## Validate Cleaning
#
# Check to see if user review count is above 20

# %%
# get count of reviews per user
print("Count of Reviews per user:") 
display(books.groupby('User_id')['review/score'].count().reset_index().rename(columns={'review/score':'review_count'}).sort_values('review_count', ascending=True).head(5))

# get count of reviews per book
print("Count of Reviews per book:")
display(books.groupby('Title')['review/score'].count().reset_index().rename(columns={'review/score':'review_count'}).sort_values('review_count', ascending=True).head(5))
# Out:
# Count of Reviews per user:
#              User_id  review_count
# 1529  A3N0E03AQD128O            21
# 166   A1AXG78TNTPDA6            21
# 1927   AGZJEUQXB2150            21
# 1515  A3MCQSIBV7QW8Q            21
# 1171  A30RI6N2MGFMFK            21
# Count of Reviews per book:
#                                            Title  review_count
# 1214  The Duke and I (Bridgerton Series, Book 1)             6
# 1688                            Whitney, My Love             7
# 254                                Carolina Moon            12
# 203                                   Black Rose            12
# 204            Black Rose (In the Garden Series)            12

# %%
# final check on data
print("Shape of data", books.shape)
print("Number of unique users", books.User_id.nunique())
print("Number of unique books", books.Title.nunique())
# Out:
# Shape of data (101149, 4)
# Number of unique users 2249
# Number of unique books 1727

# %%
# check duplicates
print("Number of duplicates:", books.duplicated().sum())

# see duplicates
print("Duplicates")
display(books[books.duplicated(keep=False)].head(10))
# Out:
# Number of duplicates: 0
# Duplicates
# Empty DataFrame
# Columns: [User_id, Title, review/score, review/text]
# Index: []

# %% [markdown]
# # Item-User Matrix

# %%
# create pivot table
books_pivot = books.pivot_table(index='User_id', columns='Title', values='review/score').fillna(0)
books_pivot.head(3)
# Out:
# Title           "A" IS FOR ALIBI  \
# User_id
# A106016KSI0YQ                0.0
# A10872FHIJAKKD               0.0
# A10A1S5NAQBT21               0.0
#
# Title           1,000 Places to See Before You Die: A Traveler's Life List  \
# User_id
# A106016KSI0YQ                                                 0.0
# A10872FHIJAKKD                                                0.0
# A10A1S5NAQBT21                                                0.0
#
# Title           1491: New Revelations of the Americas Before Columbus  \
# User_id
# A106016KSI0YQ                                                 0.0
# A10872FHIJAKKD                                                0.0
# A10A1S5NAQBT21                                                0.0
#
# Title           1632 (The Assiti Shards)  1984  1st to Die: A Novel  \
# User_id
# A106016KSI0YQ                        0.0   0.0                  0.0
# A10872FHIJAKKD                       0.0   0.0                  0.0
# A10A1S5NAQBT21                       0.0   0.0                  0.0
#
# Title           20, 000 Leagues Under the Sea  2001: A Space Odyssey  \
# User_id
# A106016KSI0YQ                             0.0                    0.0
# A10872FHIJAKKD                            0.0                    0.0
# A10A1S5NAQBT21                            0.0                    0.0
#
# Title           4 Blondes  48 Laws of Power  ...  \
# User_id                                      ...
# A106016KSI0YQ         0.0               0.0  ...
# A10872FHIJAKKD        0.0               0.0  ...
# A10A1S5NAQBT21        0.0               0.0  ...
#
# Title           Year of Wonders (Turtleback School & Library Binding Edition)  \
# User_id
# A106016KSI0YQ                                                 0.0
# A10872FHIJAKKD                                                0.0
# A10A1S5NAQBT21                                                0.0
#
# Title           Zen And The Art of Motorcycle Maintenance  \
# User_id
# A106016KSI0YQ                                         0.0
# A10872FHIJAKKD                                        0.0
# A10A1S5NAQBT21                                        0.0
#
# Title           Zen and the Art of Motorcycle Maintenance  \
# User_id
# A106016KSI0YQ                                         0.0
# A10872FHIJAKKD                                        0.0
# A10A1S5NAQBT21                                        0.0
#
# Title           Zen and the Art of Motorcycle Maintenance : An Inquiry Into Values  \
# User_id
# A106016KSI0YQ                                                 0.0
# A10872FHIJAKKD                                                0.0
# A10A1S5NAQBT21                                                0.0
#
# Title           Zen and the Art of Motorcycle Maintenance : An Inquiry into Values  \
# User_id
# A106016KSI0YQ                                                 0.0
# A10872FHIJAKKD                                                0.0
# A10A1S5NAQBT21                                                0.0
#
# Title           Zorro - A Novel  \
# User_id
# A106016KSI0YQ               0.0
# A10872FHIJAKKD              0.0
# A10A1S5NAQBT21              0.0
#
# Title           everything on this page is for Treasure Island  \
# User_id
# A106016KSI0YQ                                              0.0
# A10872FHIJAKKD                                             0.0
# A10A1S5NAQBT21                                             0.0
#
# Title           prince caspian: the return to narnia  \
# User_id
# A106016KSI0YQ                                    0.0
# A10872FHIJAKKD                                   0.0
# A10A1S5NAQBT21                                   0.0
#
# Title           the Picture of Dorian Gray  the illustrated man
# User_id
# A106016KSI0YQ                          0.0                  0.0
# A10872FHIJAKKD                         0.0                  0.0
# A10A1S5NAQBT21                         5.0                  0.0
#
# [3 rows x 1727 columns]

# %% [markdown]
# # Item Based Collaborative Filtering
#
# 1. Have User Item matrix
# 2. Calculate similarity (cosine similarity)
# 3. Calculate weighted average of ratings
# 4. Fill in missing values with predicted ratings

# %%
# SIMILARITY MATRIX ########################################## 

# Calculate item-item similarity matrix
item_similarity_matrix = cosine_similarity(books_pivot.T)  # Transpose the matrix to have items as rows


# PREDICTED RATINGS ########################################## 

# create function to predict ratings
def predict_ratings(user_ratings, item_similarity_matrix):
    
    # Initialize an array to store predicted ratings
    predicted_ratings = np.zeros(user_ratings.shape)

    # Iterate through each user
    for user_id in range(user_ratings.shape[0]):
        
        # Find unrated books (where user_ratings == 0)
        unrated_books = np.where(user_ratings[user_id, :] == 0)[0]

        # Iterate through unrated books
        for book_id in unrated_books:
            # Calculate the predicted rating for the unrated book
            rated_books = np.where(user_ratings[user_id, :] > 0)[0]
            predicted_rating = np.sum(
                user_ratings[user_id, rated_books] * item_similarity_matrix[book_id, rated_books]
            ) / np.sum(np.abs(item_similarity_matrix[book_id, rated_books]))

            # Assign the predicted rating to the user_ratings matrix
            predicted_ratings[user_id, book_id] = predicted_rating

    return predicted_ratings

# apply function to get predicted ratings
predicted_ratings = predict_ratings(books_pivot.values, item_similarity_matrix)

# FILL IN MATRIX ###############################################

# Fill in the matrix with predicted ratings
filled_matrix = books_pivot.copy()
filled_matrix = filled_matrix.to_numpy()
filled_matrix[filled_matrix == 0] = predicted_ratings[filled_matrix == 0]
filled_matrix = pd.DataFrame(filled_matrix, columns=books_pivot.columns, index=books_pivot.index)

# %%
filled_matrix
# Out:
# Title           "A" IS FOR ALIBI  \
# User_id
# A106016KSI0YQ           3.698780
# A10872FHIJAKKD          5.000000
# A10A1S5NAQBT21          4.672861
# A10BZSGALQPS0V          3.667069
# A10ETB3064YV0F          4.288135
# ...                          ...
# AZJ1N5LS6Q0FD           3.000000
# AZM09BO1FD418           3.473763
# AZSNQ9FYC5SQO           5.000000
# AZSV99SDJC242           4.176972
# AZWG3PF80735Q           3.828744
#
# Title           1,000 Places to See Before You Die: A Traveler's Life List  \
# User_id
# A106016KSI0YQ                                            3.807621
# A10872FHIJAKKD                                           4.785000
# A10A1S5NAQBT21                                           5.000000
# A10BZSGALQPS0V                                           4.292849
# A10ETB3064YV0F                                           3.847626
# ...                                                           ...
# AZJ1N5LS6Q0FD                                            3.000000
# AZM09BO1FD418                                            3.041298
# AZSNQ9FYC5SQO                                            5.000000
# AZSV99SDJC242                                            4.458849
# AZWG3PF80735Q                                            3.912092
#
# Title           1491: New Revelations of the Americas Before Columbus  \
# User_id
# A106016KSI0YQ                                            3.575590
# A10872FHIJAKKD                                           4.847160
# A10A1S5NAQBT21                                           5.000000
# A10BZSGALQPS0V                                           4.054266
# A10ETB3064YV0F                                           3.955799
# ...                                                           ...
# AZJ1N5LS6Q0FD                                            3.000000
# AZM09BO1FD418                                            3.190770
# AZSNQ9FYC5SQO                                            5.000000
# AZSV99SDJC242                                            4.279156
# AZWG3PF80735Q                                            4.089405
#
# Title           1632 (The Assiti Shards)      1984  1st to Die: A Novel  \
# User_id
# A106016KSI0YQ                   3.946012  3.974340             3.883530
# A10872FHIJAKKD                  4.939276  4.889311             4.748068
# A10A1S5NAQBT21                  5.000000  4.532852             4.303542
# A10BZSGALQPS0V                  4.167092  4.057489             4.163900
# A10ETB3064YV0F                  4.515917  4.316896             4.131319
# ...                                  ...       ...                  ...
# AZJ1N5LS6Q0FD                   3.000000  3.000000             3.000000
# AZM09BO1FD418                   4.061257  4.121433             3.747529
# AZSNQ9FYC5SQO                   5.000000  5.000000             5.000000
# AZSV99SDJC242                   4.277241  4.416627             4.360988
# AZWG3PF80735Q                   4.260756  4.220967             3.943865
#
# Title           20, 000 Leagues Under the Sea  2001: A Space Odyssey  \
# User_id
# A106016KSI0YQ                        4.217895               3.956143
# A10872FHIJAKKD                       4.936126               4.930877
# A10A1S5NAQBT21                       4.334120               4.662730
# A10BZSGALQPS0V                       3.960534               4.100171
# A10ETB3064YV0F                       4.140898               4.261409
# ...                                       ...                    ...
# AZJ1N5LS6Q0FD                        3.000000               3.000000
# AZM09BO1FD418                        4.361101               4.201540
# AZSNQ9FYC5SQO                        5.000000               5.000000
# AZSV99SDJC242                        4.280244               4.390886
# AZWG3PF80735Q                        4.174612               4.191873
#
# Title           4 Blondes  48 Laws of Power  ...  \
# User_id                                      ...
# A106016KSI0YQ    3.379133          3.647744  ...
# A10872FHIJAKKD   5.000000          5.000000  ...
# A10A1S5NAQBT21   5.000000          4.784756  ...
# A10BZSGALQPS0V   4.345257          4.116741  ...
# A10ETB3064YV0F   3.934975          3.595715  ...
# ...                   ...               ...  ...
# AZJ1N5LS6Q0FD    3.000000          3.000000  ...
# AZM09BO1FD418    2.000000          3.000000  ...
# AZSNQ9FYC5SQO    5.000000          5.000000  ...
# AZSV99SDJC242    3.748792          4.179858  ...
# AZWG3PF80735Q    4.025519          3.983773  ...
#
# Title           Year of Wonders (Turtleback School & Library Binding Edition)  \
# User_id
# A106016KSI0YQ                                            3.712372
# A10872FHIJAKKD                                           4.421572
# A10A1S5NAQBT21                                           4.698969
# A10BZSGALQPS0V                                           4.158555
# A10ETB3064YV0F                                           4.318098
# ...                                                           ...
# AZJ1N5LS6Q0FD                                            3.000000
# AZM09BO1FD418                                            3.994209
# AZSNQ9FYC5SQO                                            5.000000
# AZSV99SDJC242                                            4.386042
# AZWG3PF80735Q                                            3.887030
#
# Title           Zen And The Art of Motorcycle Maintenance  \
# User_id
# A106016KSI0YQ                                    3.935393
# A10872FHIJAKKD                                   4.935530
# A10A1S5NAQBT21                                   4.622180
# A10BZSGALQPS0V                                   4.079098
# A10ETB3064YV0F                                   3.752009
# ...                                                   ...
# AZJ1N5LS6Q0FD                                    3.000000
# AZM09BO1FD418                                    3.868362
# AZSNQ9FYC5SQO                                    5.000000
# AZSV99SDJC242                                    4.326155
# AZWG3PF80735Q                                    4.299049
#
# Title           Zen and the Art of Motorcycle Maintenance  \
# User_id
# A106016KSI0YQ                                    3.935393
# A10872FHIJAKKD                                   4.935530
# A10A1S5NAQBT21                                   4.622180
# A10BZSGALQPS0V                                   4.079098
# A10ETB3064YV0F                                   3.752009
# ...                                                   ...
# AZJ1N5LS6Q0FD                                    3.000000
# AZM09BO1FD418                                    3.868362
# AZSNQ9FYC5SQO                                    5.000000
# AZSV99SDJC242                                    4.326155
# AZWG3PF80735Q                                    4.299049
#
# Title           Zen and the Art of Motorcycle Maintenance : An Inquiry Into Values  \
# User_id
# A106016KSI0YQ                                            3.935393
# A10872FHIJAKKD                                           4.935530
# A10A1S5NAQBT21                                           4.622180
# A10BZSGALQPS0V                                           4.079098
# A10ETB3064YV0F                                           3.752009
# ...                                                           ...
# AZJ1N5LS6Q0FD                                            3.000000
# AZM09BO1FD418                                            3.868362
# AZSNQ9FYC5SQO                                            5.000000
# AZSV99SDJC242                                            4.326155
# AZWG3PF80735Q                                            4.299049
#
# Title           Zen and the Art of Motorcycle Maintenance : An Inquiry into Values  \
# User_id
# A106016KSI0YQ                                            3.935393
# A10872FHIJAKKD                                           4.935530
# A10A1S5NAQBT21                                           4.622180
# A10BZSGALQPS0V                                           4.079098
# A10ETB3064YV0F                                           3.752009
# ...                                                           ...
# AZJ1N5LS6Q0FD                                            3.000000
# AZM09BO1FD418                                            3.868362
# AZSNQ9FYC5SQO                                            5.000000
# AZSV99SDJC242                                            4.326155
# AZWG3PF80735Q                                            4.299049
#
# Title           Zorro - A Novel  \
# User_id
# A106016KSI0YQ          3.726164
# A10872FHIJAKKD         5.000000
# A10A1S5NAQBT21         5.000000
# A10BZSGALQPS0V         4.179283
# A10ETB3064YV0F         4.180216
# ...                         ...
# AZJ1N5LS6Q0FD          3.000000
# AZM09BO1FD418          3.214507
# AZSNQ9FYC5SQO          5.000000
# AZSV99SDJC242          4.586209
# AZWG3PF80735Q          3.957435
#
# Title           everything on this page is for Treasure Island  \
# User_id
# A106016KSI0YQ                                         4.132121
# A10872FHIJAKKD                                        4.839874
# A10A1S5NAQBT21                                        4.302350
# A10BZSGALQPS0V                                        4.132759
# A10ETB3064YV0F                                        3.957032
# ...                                                        ...
# AZJ1N5LS6Q0FD                                         3.000000
# AZM09BO1FD418                                         4.155484
# AZSNQ9FYC5SQO                                         5.000000
# AZSV99SDJC242                                         4.249465
# AZWG3PF80735Q                                         4.112088
#
# Title           prince caspian: the return to narnia  \
# User_id
# A106016KSI0YQ                               4.236961
# A10872FHIJAKKD                              4.870104
# A10A1S5NAQBT21                              4.426234
# A10BZSGALQPS0V                              4.390096
# A10ETB3064YV0F                              4.332043
# ...                                              ...
# AZJ1N5LS6Q0FD                               3.000000
# AZM09BO1FD418                               4.288809
# AZSNQ9FYC5SQO                               5.000000
# AZSV99SDJC242                               4.069510
# AZWG3PF80735Q                               4.063511
#
# Title           the Picture of Dorian Gray  the illustrated man
# User_id
# A106016KSI0YQ                     3.973735             3.991655
# A10872FHIJAKKD                    4.852613             4.879402
# A10A1S5NAQBT21                    5.000000             4.416384
# A10BZSGALQPS0V                    3.985937             4.313282
# A10ETB3064YV0F                    4.094625             3.929897
# ...                                    ...                  ...
# AZJ1N5LS6Q0FD                     3.000000             3.000000
# AZM09BO1FD418                     4.075726             4.126608
# AZSNQ9FYC5SQO                     5.000000             5.000000
# AZSV99SDJC242                     4.309007             4.535623
# AZWG3PF80735Q                     4.198473             3.994366
#
# [2249 rows x 1727 columns]

# %% [markdown]
# # Evaluation of Model
#
# 1. Split data into train and test
# 2. Apply steps 1-4 above: Rebuild the filled in matrix
# 3. Calculate MAE, RMSE, MSE

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Step 1: Create a copy of the original matrix to store hidden ratings
training_matrix = books_pivot.copy()

# Iterate through each user
for user_id in range(training_matrix.shape[0]):
    # Find the indices of rated books for this user
    rated_books = np.where(training_matrix.iloc[user_id, :] > 0)[0]
    
    # Randomly select 5 ratings to hide (if available)
    num_to_hide = min(5, len(rated_books))
    hidden_indices = np.random.choice(rated_books, num_to_hide, replace=False)
    
    # Set the selected ratings to 0 in the hidden ratings matrix
    training_matrix.iloc[user_id, hidden_indices] = 0

# Step 2: Rebuild the Filled Matrix (use your existing predict_ratings function)
item_similarity_matrix = cosine_similarity(training_matrix.T)
predicted_ratings = predict_ratings(training_matrix.values, item_similarity_matrix)
# Out:
# C:\Users\e1002902\AppData\Local\Temp\ipykernel_16128\1781665563.py:18: RuntimeWarning: invalid value encountered in scalar divide
#   predicted_rating = np.sum(

# %%
# Step 3: Calculate Evaluation Metrics
# Extract hidden ratings and corresponding predicted ratings
hidden_ratings = training_matrix.values[training_matrix.values != 0]
predicted_hidden_ratings = predicted_ratings[training_matrix.values != 0]

# Calculate MAE, MSE, and RMSE
mae = mean_absolute_error(hidden_ratings, predicted_hidden_ratings)
mse = mean_squared_error(hidden_ratings, predicted_hidden_ratings)
rmse = np.sqrt(mse)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Mean Absolute Error (MAE): 4.303012298252018
# Mean Squared Error (MSE): 19.43548823977144
# Root Mean Squared Error (RMSE): 4.408569863319786

# %%
# Out:
# (86497,)

# %% [markdown]
# # Testing Area (Ignore)

# %%
x = pd.read_csv(r"C:\Users\e1002902\Documents\GitHub Repository\Masters-Dissertation\Code\temp_data.csv", index_col=0)
x
# Out:
#         book1  book2  book3  book4  book5  book6  book7  book8  book9  book10
# user1       0      0      2      5      4      3      4      4      4       4
# user2       4      0      3      5      0      0      0      0      0       4
# user3       0      3      4      4      0      2      0      0      0       0
# user4       0      0      3      5      4      0      0      0      0       0
# user5       3      4      0      4      4      0      5      5      5       5
# user6       4      5      0      0      0      0      4      2      2       0
# user7       2      2      0      0      0      0      5      3      3       3
# user8       0      5      4      0      4      3      0      0      0       0
# user9       0      5      4      0      5      2      0      2      2       0
# user10      0      0      0      0      5      0      4      4      4       4
# user11      4      2      2      0      5      0      5      5      5       0
# user12      5      5      3      0      2      3      3      3      3       0

# %%
np.random.seed(10)  # You can use any integer value as the seed
for user_id in range(x.shape[0]):
    rated_books = np.where(x.iloc[user_id, :] > 0)[0]
    print(user_id)
    print(rated_books)
    hidden_indices = np.random.choice(rated_books, min(2, len(rated_books)), replace=False)
    print(hidden_indices)
    x.iloc[user_id, hidden_indices] = 0
# Out:
# 0
# [2 3 4 5 6 7 8 9]
# [4 5]
# 1
# [0 2 3 9]
# [3 9]
# 2
# [1 2 3 5]
# [5 1]
# 3
# [2 3 4]
# [4 2]
# 4
# [0 1 3 4 6 7 8 9]
# [9 1]
# 5
# [0 1 6 7 8]
# [8 1]
# 6
# [0 1 6 7 8 9]
# [8 9]
# 7
# [1 2 4 5]
# [1 5]
# 8
# [1 2 4 5 7 8]
# [1 7]
# 9
# [4 6 7 8 9]
# [6 4]
# 10
# [0 1 2 4 6 7 8]
# [2 0]
# 11
# [0 1 2 4 5 6 7 8]
# [1 7]

# %%
x
# Out:
#         book1  book2  book3  book4  book5  book6  book7  book8  book9  book10
# user1       0      0      2      5      4      3      4      4      4       4
# user2       0      0      3      0      0      0      0      0      0       4
# user3       0      3      4      4      0      2      0      0      0       0
# user4       0      0      0      5      0      0      0      0      0       0
# user5       3      4      0      4      4      0      5      5      5       5
# user6       4      5      0      0      0      0      4      2      2       0
# user7       2      2      0      0      0      0      5      3      3       3
# user8       0      5      4      0      4      3      0      0      0       0
# user9       0      5      4      0      5      2      0      2      2       0
# user10      0      0      0      0      5      0      4      4      4       4
# user11      4      2      2      0      5      0      5      5      5       0
# user12      5      5      3      0      2      3      3      3      3       0

# %%
# where 'HIDDEN' make 0
testing = testing.replace('HIDDEN', 0)
item_similarity_matrix = cosine_similarity(testing.T)
predicted_ratings = predict_ratings(testing.values, item_similarity_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\e1002902\Documents\GitHub Repository\Masters-Dissertation\Code\item_collab_filtering.ipynb Cell 28 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/e1002902/Documents/GitHub%20Repository/Masters-Dissertation/Code/item_collab_filtering.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> # where 'HIDDEN' make 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/e1002902/Documents/GitHub%20Repository/Masters-Dissertation/Code/item_collab_filtering.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a> testing = testing.replace('HIDDEN', 0)
#       <a href='vscode-notebook-cell:/c%3A/Users/e1002902/Documents/GitHub%20Repository/Masters-Dissertation/Code/item_collab_filtering.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a> item_similarity_matrix = cosine_similarity(testing.T)
#       <a href='vscode-notebook-cell:/c%3A/Users/e1002902/Documents/GitHub%20Repository/Masters-Dissertation/Code/item_collab_filtering.ipynb#X42sZmlsZQ%3D%3D?line=3'>4</a> predicted_ratings = predict_ratings(testing.values, item_similarity_matrix)
#
# NameError: name 'testing' is not defined

# %%
testing
# Out:
# Title           1,000 Places to See Before You Die: A Traveler's Life List  \
# User_id
# A10872FHIJAKKD                                                0.0
# A10A1S5NAQBT21                                                2.0
# A10BZSGALQPS0V                                                0.0
# A10ETB3064YV0F                                                0.0
# A10KKJMBY5L7TK                                                0.0
# A10LWBOIZCF2QT                                                0.0
# A10T0OW97SFBB                                                 0.0
# A10X0JN8KTK89H                                                4.0
# A10Y3OZWENAQ6W                                                0.0
# A1129LM24YWSZV                                                0.0
#
# Title           1491: New Revelations of the Americas Before Columbus  \
# User_id
# A10872FHIJAKKD                                                2.0
# A10A1S5NAQBT21                                                3.0
# A10BZSGALQPS0V                                                0.0
# A10ETB3064YV0F                                                0.0
# A10KKJMBY5L7TK                                                2.0
# A10LWBOIZCF2QT                                                0.0
# A10T0OW97SFBB                                                 1.0
# A10X0JN8KTK89H                                                0.0
# A10Y3OZWENAQ6W                                                0.0
# A1129LM24YWSZV                                                0.0
#
# Title           1632 (The Assiti Shards)  1984  1st to Die: A Novel  \
# User_id
# A10872FHIJAKKD                       2.0   0.0                  3.0
# A10A1S5NAQBT21                       0.0   5.0                  0.0
# A10BZSGALQPS0V                       0.0   0.0                  5.0
# A10ETB3064YV0F                       4.0   0.0                  0.0
# A10KKJMBY5L7TK                       1.0   1.0                  0.0
# A10LWBOIZCF2QT                       3.0   0.0                  0.0
# A10T0OW97SFBB                        0.0   0.0                  0.0
# A10X0JN8KTK89H                       0.0   5.0                  0.0
# A10Y3OZWENAQ6W                       0.0   4.0                  0.0
# A1129LM24YWSZV                       4.0   4.0                  0.0
#
# Title           20, 000 Leagues Under the Sea  2001: A Space Odyssey  \
# User_id
# A10872FHIJAKKD                            0.0                    0.0
# A10A1S5NAQBT21                            4.0                    0.0
# A10BZSGALQPS0V                            0.0                    1.0
# A10ETB3064YV0F                            0.0                    0.0
# A10KKJMBY5L7TK                            0.0                    4.0
# A10LWBOIZCF2QT                            0.0                    5.0
# A10T0OW97SFBB                             0.0                    2.0
# A10X0JN8KTK89H                            2.0                    0.0
# A10Y3OZWENAQ6W                            0.0                    3.0
# A1129LM24YWSZV                            5.0                    4.0
#
# Title           4 Blondes  48 Laws of Power
# User_id
# A10872FHIJAKKD        4.0               0.0
# A10A1S5NAQBT21        0.0               0.0
# A10BZSGALQPS0V        1.0               3.0
# A10ETB3064YV0F        0.0               1.0
# A10KKJMBY5L7TK        0.0               1.0
# A10LWBOIZCF2QT        0.0               0.0
# A10T0OW97SFBB         1.0               1.0
# A10X0JN8KTK89H        0.0               1.0
# A10Y3OZWENAQ6W        0.0               0.0
# A1129LM24YWSZV        0.0               0.0

# %%
# Find unrated books (where user_ratings == 0)
unrated_books = np.where(testing.values[1, :] == 0)[0]
unrated_books
# Out:
# array([2, 4, 6, 7, 8], dtype=int64)

# %%
rated_books = np.where(testing.values[1, :] > 0)[0]
rated_books
# Out:
# array([0, 1, 3, 5], dtype=int64)

# %%
item_similarity_matrix[2, rated_books]
# Out:
# array([0.        , 0.20851441, 0.27512557, 0.43958698])

# %%
# Calculate the predicted rating for the unrated book

predicted_rating = np.sum(
    testing[1, rated_books] * item_similarity_matrix[2, rated_books]
) / np.sum(np.abs(item_similarity_matrix[book_id, rated_books]))

predicted_rating

# %%
pd.DataFrame(predicted_ratings, columns=testing.columns, index=testing.index).round(2)
# Out:
# Title           1,000 Places to See Before You Die: A Traveler's Life List  \
# User_id
# A10872FHIJAKKD                                               2.00
# A10A1S5NAQBT21                                               0.00
# A10BZSGALQPS0V                                               3.00
# A10ETB3064YV0F                                               1.00
# A10KKJMBY5L7TK                                               1.24
# A10LWBOIZCF2QT                                                NaN
# A10T0OW97SFBB                                                1.00
# A10X0JN8KTK89H                                               0.00
# A10Y3OZWENAQ6W                                               4.00
# A1129LM24YWSZV                                               4.42
#
# Title           1491: New Revelations of the Americas Before Columbus  \
# User_id
# A10872FHIJAKKD                                               0.00
# A10A1S5NAQBT21                                               0.00
# A10BZSGALQPS0V                                               2.12
# A10ETB3064YV0F                                               2.55
# A10KKJMBY5L7TK                                               0.00
# A10LWBOIZCF2QT                                               4.15
# A10T0OW97SFBB                                                0.00
# A10X0JN8KTK89H                                               3.28
# A10Y3OZWENAQ6W                                               3.61
# A1129LM24YWSZV                                               4.31
#
# Title           1632 (The Assiti Shards)  1984  1st to Die: A Novel  \
# User_id
# A10872FHIJAKKD                      0.00  2.00                 0.00
# A10A1S5NAQBT21                      4.07  0.00                 3.00
# A10BZSGALQPS0V                      1.81  1.61                 0.00
# A10ETB3064YV0F                      0.00  2.80                 1.53
# A10KKJMBY5L7TK                      0.00  0.00                 1.45
# A10LWBOIZCF2QT                      0.00  4.20                 3.80
# A10T0OW97SFBB                       1.47  1.40                 1.06
# A10X0JN8KTK89H                      2.68  0.00                 1.00
# A10Y3OZWENAQ6W                      3.31  0.00                 3.00
# A1129LM24YWSZV                      0.00  0.00                 4.00
#
# Title           20, 000 Leagues Under the Sea  2001: A Space Odyssey  \
# User_id
# A10872FHIJAKKD                           2.00                   2.25
# A10A1S5NAQBT21                           0.00                   4.13
# A10BZSGALQPS0V                           1.38                   0.00
# A10ETB3064YV0F                           3.53                   3.02
# A10KKJMBY5L7TK                           1.70                   0.00
# A10LWBOIZCF2QT                           3.89                   0.00
# A10T0OW97SFBB                            1.41                   0.00
# A10X0JN8KTK89H                           0.00                   2.89
# A10Y3OZWENAQ6W                           3.70                   0.00
# A1129LM24YWSZV                           0.00                   0.00
#
# Title           4 Blondes  48 Laws of Power
# User_id
# A10872FHIJAKKD       0.00              2.90
# A10A1S5NAQBT21       3.00              3.28
# A10BZSGALQPS0V       0.00              0.00
# A10ETB3064YV0F       2.55              0.00
# A10KKJMBY5L7TK       1.67              0.00
# A10LWBOIZCF2QT       3.46              4.18
# A10T0OW97SFBB        0.00              0.00
# A10X0JN8KTK89H       1.00              0.00
# A10Y3OZWENAQ6W       3.00              3.38
# A1129LM24YWSZV       4.00              4.11

# %%
predicted_hidden_ratings = predicted_ratings[training_matrix.values != 0]
